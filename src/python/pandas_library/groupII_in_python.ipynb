# %%
import pandas as pd
import numpy as np

# %%
name,field1,field2,field3 = [],[],[],[]

for w in range(1,10):
    for x in range(20,50,10):
        for y in range(-100,-400,-100):
            for z in range(1000,4000,1000):
                name.append(str(w))
                field1.append(x)
                field2.append(y)
                field3.append(z)

# %%
df = pd.DataFrame({
    "name":name,
    "field1":field1,
    "field2":field2,
    "field3":field3
})

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 238    9      40    -200    2000
# 239    9      40    -200    3000
# 240    9      40    -300    1000
# 241    9      40    -300    2000
# 242    9      40    -300    3000
#
# [243 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    243 non-null    object
#  1   field1  243 non-null    int64
#  2   field2  243 non-null    int64
#  3   field3  243 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.7+ KB

# %% [markdown]
# aggregate function in dataframe

# %%
df.max()
# Out:
# name         9
# field1      40
# field2    -100
# field3    3000
# dtype: object

# %%
df.min()
# Out:
# name         1
# field1      20
# field2    -300
# field3    1000
# dtype: object

# %%
df.sum()
# Out:
# name      1111111111111111111111111112222222222222222222...
# field1                                                 7290
# field2                                               -48600
# field3                                               486000
# dtype: object

# %%
df.mean()
# Out:
# name      4572473708276176912569646155081459610408630079...
# field1                                                 30.0
# field2                                               -200.0
# field3                                               2000.0
# dtype: object

# %%
df.median()
# Out:
# name         5.0
# field1      30.0
# field2    -200.0
# field3    2000.0
# dtype: object

# %%
df.count()
# Out:
# name      243
# field1    243
# field2    243
# field3    243
# dtype: int64

# %%
df.value_counts()
# Out:
# 243

# %%
group_data = df.groupby(by = "name")

# %%
group_data

# %%
group_data.max()
# Out:
#       field1  field2  field3
# name
# 1         40    -100    3000
# 2         40    -100    3000
# 3         40    -100    3000
# 4         40    -100    3000
# 5         40    -100    3000
# 6         40    -100    3000
# 7         40    -100    3000
# 8         40    -100    3000
# 9         40    -100    3000

# %%
group_data.apply(print)
# Out:
#    name  field1  field2  field3
# 0     1      20    -100    1000
# 1     1      20    -100    2000
# 2     1      20    -100    3000
# 3     1      20    -200    1000
# 4     1      20    -200    2000
# 5     1      20    -200    3000
# 6     1      20    -300    1000
# 7     1      20    -300    2000
# 8     1      20    -300    3000
# 9     1      30    -100    1000
# 10    1      30    -100    2000
# 11    1      30    -100    3000
# 12    1      30    -200    1000
# 13    1      30    -200    2000
# 14    1      30    -200    3000
# 15    1      30    -300    1000
# 16    1      30    -300    2000
# 17    1      30    -300    3000
# 18    1      40    -100    1000
# 19    1      40    -100    2000
# 20    1      40    -100    3000
# 21    1      40    -200    1000
# 22    1      40    -200    2000
# 23    1      40    -200    3000
# 24    1      40    -300    1000
# 25    1      40    -300    2000
# 26    1      40    -300    3000
#    name  field1  field2  field3
# ...

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 238    9      40    -200    2000
# 239    9      40    -200    3000
# 240    9      40    -300    1000
# 241    9      40    -300    2000
# 242    9      40    -300    3000
#
# [243 rows x 4 columns]

# %%
df.loc[len(df)] = ["1",32,34,2000]

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 239    9      40    -200    3000
# 240    9      40    -300    1000
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34    2000
#
# [244 rows x 4 columns]

# %%
group_data = df.groupby(by = "name")

# %%
group_data.max()
# Out:
#       field1  field2  field3
# name
# 1         40      34    3000
# 2         40    -100    3000
# 3         40    -100    3000
# 4         40    -100    3000
# 5         40    -100    3000
# 6         40    -100    3000
# 7         40    -100    3000
# 8         40    -100    3000
# 9         40    -100    3000

# %%
group_data.agg({"field2":["min","max"]})
# Out:
#      field2
#         min  max
# name
# 1      -300   34
# 2      -300 -100
# 3      -300 -100
# 4      -300 -100
# 5      -300 -100
# 6      -300 -100
# 7      -300 -100
# 8      -300 -100
# 9      -300 -100

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 239    9      40    -200    3000
# 240    9      40    -300    1000
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34    2000
#
# [244 rows x 4 columns]

# %%
df.loc[len(df)] = ["2",1000,23,34000]

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34    2000
# 244    2    1000      23   34000
# 245    2    1000      23   34000
#
# [246 rows x 4 columns]

# %%
df.iat[245,3] = 4000

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34    2000
# 244    2    1000      23   34000
# 245    2    1000      23    4000
#
# [246 rows x 4 columns]

# %%
df.at[243,"field3"] = 435

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34     435
# 244    2    1000      23   34000
# 245    2    1000      23    4000
#
# [246 rows x 4 columns]

# %%
df.loc[245,"field1"] = 3000

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34     435
# 244    2    1000      23   34000
# 245    2    3000      23    4000
#
# [246 rows x 4 columns]

# %%
df.iloc[245,1] = 231

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      40    -300    2000
# 242    9      40    -300    3000
# 243    1      32      34     435
# 244    2    1000      23   34000
# 245    2     231      23    4000
#
# [246 rows x 4 columns]

# %%
df.loc[241:,"field1":] = 4000

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9    4000    4000    4000
# 242    9    4000    4000    4000
# 243    1    4000    4000    4000
# 244    2    4000    4000    4000
# 245    2    4000    4000    4000
#
# [246 rows x 4 columns]

# %%
df.iloc[241:,1:] = 9000

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9    9000    9000    9000
# 242    9    9000    9000    9000
# 243    1    9000    9000    9000
# 244    2    9000    9000    9000
# 245    2    9000    9000    9000
#
# [246 rows x 4 columns]

# %%
df.iloc[241:,1:] = [12,23,34]

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      12      23      34
# 242    9      12      23      34
# 243    1      12      23      34
# 244    2      12      23      34
# 245    2      12      23      34
#
# [246 rows x 4 columns]

# %%
df.loc[241:,"field1":] = [34,54,32]

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      34      54      32
# 242    9      34      54      32
# 243    1      34      54      32
# 244    2      34      54      32
# 245    2      34      54      32
#
# [246 rows x 4 columns]

# %%
df.loc[244:,"field1":] = [[34,21,23],[24,67,54]]

# %%
df
# Out:
#     name  field1  field2  field3
# 0      1      20    -100    1000
# 1      1      20    -100    2000
# 2      1      20    -100    3000
# 3      1      20    -200    1000
# 4      1      20    -200    2000
# ..   ...     ...     ...     ...
# 241    9      34      54      32
# 242    9      34      54      32
# 243    1      34      54      32
# 244    2      34      21      23
# 245    2      24      67      54
#
# [246 rows x 4 columns]

# %%
data1 = {'Name': ['Alice', 'Bob', 'Charlie', 'David'] * 5,
        'Age': [25, 30, 35, 40] * 5,
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'] * 5}

df1 = pd.DataFrame(data1)

# %%
data2 = {'Name': ['Alice', 'Bob', 'Charlie', 'David'] * 5,
        'Id': [25, 30, 35, 40] * 5,
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'] * 5}

df2 = pd.DataFrame(data2)

# %%
merge_df = pd.merge(df1,df2,how = "inner",left_on = "Age",right_on = "Id")

# %%
merge_df
# Out:
#    Name_x  Age    City_x Name_y  Id    City_y
# 0   Alice   25  New York  Alice  25  New York
# 1   Alice   25  New York  Alice  25  New York
# 2   Alice   25  New York  Alice  25  New York
# 3   Alice   25  New York  Alice  25  New York
# 4   Alice   25  New York  Alice  25  New York
# ..    ...  ...       ...    ...  ..       ...
# 95  David   40   Houston  David  40   Houston
# 96  David   40   Houston  David  40   Houston
# 97  David   40   Houston  David  40   Houston
# 98  David   40   Houston  David  40   Houston
# 99  David   40   Houston  David  40   Houston
#
# [100 rows x 6 columns]

# %%
merge_df.drop_duplicates(subset = ["Name_x"])
# Out:
#      Name_x  Age       City_x   Name_y  Id       City_y
# 0     Alice   25     New York    Alice  25     New York
# 25      Bob   30  Los Angeles      Bob  30  Los Angeles
# 50  Charlie   35      Chicago  Charlie  35      Chicago
# 75    David   40      Houston    David  40      Houston

# %%
md = merge_df.sort_values(by = ["Id"])

# %%
a = md.drop_duplicates(subset = ["Name_x"])

# %%
b = a["Age"][a["Age"]>32]

# %%
b
# Out:
# 64    35
# 89    40
# Name: Age, dtype: int64

# %%
refine_data = merge_df[merge_df["Age"].isin(b)]

# %%
b.iat[0] = 40

# %%
b
# Out:
# 64    40
# 89    40
# Name: Age, dtype: int64

# %%
refine_data[refine_data["Age"].isin(b)]
# Out:
#    Name_x  Age   City_x Name_y  Id   City_y
# 75  David   40  Houston  David  40  Houston
# 76  David   40  Houston  David  40  Houston
# 77  David   40  Houston  David  40  Houston
# 78  David   40  Houston  David  40  Houston
# 79  David   40  Houston  David  40  Houston
# 80  David   40  Houston  David  40  Houston
# 81  David   40  Houston  David  40  Houston
# 82  David   40  Houston  David  40  Houston
# 83  David   40  Houston  David  40  Houston
# 84  David   40  Houston  David  40  Houston
# 85  David   40  Houston  David  40  Houston
# 86  David   40  Houston  David  40  Houston
# 87  David   40  Houston  David  40  Houston
# 88  David   40  Houston  David  40  Houston
# 89  David   40  Houston  David  40  Houston
# 90  David   40  Houston  David  40  Houston
# 91  David   40  Houston  David  40  Houston
# 92  David   40  Houston  David  40  Houston
# 93  David   40  Houston  David  40  Houston
# 94  David   40  Houston  David  40  Houston
# ...

# %%
merge_df["Name_x"].value_counts()["Alice"]
# Out:
# 25

# %%
merge_df
# Out:
#    Name_x  Age    City_x Name_y  Id    City_y
# 0   Alice   25  New York  Alice  25  New York
# 1   Alice   25  New York  Alice  25  New York
# 2   Alice   25  New York  Alice  25  New York
# 3   Alice   25  New York  Alice  25  New York
# 4   Alice   25  New York  Alice  25  New York
# ..    ...  ...       ...    ...  ..       ...
# 95  David   40   Houston  David  40   Houston
# 96  David   40   Houston  David  40   Houston
# 97  David   40   Houston  David  40   Houston
# 98  David   40   Houston  David  40   Houston
# 99  David   40   Houston  David  40   Houston
#
# [100 rows x 6 columns]

# %%
merge_df.loc[1:5,"Age"] = 20

# %%
grp = merge_df.groupby(by=["Name_x"])

# %%
def cancelation(rows):
    return  rows["Age"].value_counts().get(20,np.nan)

# %%
grp.apply(cancelation)
# Out:
# Name_x
# Alice      5.0
# Bob        NaN
# Charlie    NaN
# David      NaN
# dtype: float64

# %%
type(grp.apply(lambda x : x[["Name_x","City_x"]].iloc[0]))
# Out:
# pandas.core.frame.DataFrame

# %%
grp

# %%
grp.apply(lambda x : x.head(1))
# Out:
#              Name_x  Age       City_x   Name_y  Id       City_y
# Name_x
# Alice   0     Alice   25     New York    Alice  25     New York
# Bob     25      Bob   30  Los Angeles      Bob  30  Los Angeles
# Charlie 50  Charlie   35      Chicago  Charlie  35      Chicago
# David   75    David   40      Houston    David  40      Houston
