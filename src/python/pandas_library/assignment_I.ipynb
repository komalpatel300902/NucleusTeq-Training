# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Employees.csv")

# %%
df
# Out:
#     first_name    last_name                department  \
# 0     Carmelia       Atcock                     Sales
# 1       Lorine      Chattoe           Human Resources
# 2       Isiahi     Scholtis  Research and Development
# 3        Hardy     Roglieri                  Training
# 4    Jacquette        Duffy               Engineering
# ..         ...          ...                       ...
# 195    Christa         Tite                  Training
# 196    Eadmund          Gon                  Training
# 197     Yvette      Brunker                  Services
# 198    Adelind  Stallworthy                 Marketing
# 199      Ollie    Dovydenas                   Support
#
#                                email    salary
# 0    catcock0@scientificamerican.com       NaN
# 1          lchattoe1@hugedomains.com       NaN
# 2         ischoltis2@accuweather.com     94297
# 3             hroglieri3@squidoo.com       NaN
# 4              jduffy4@shinystat.com  365-0023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  200 non-null    object
#  1   last_name   200 non-null    object
#  2   department  200 non-null    object
#  3   email       200 non-null    object
#  4   salary      95 non-null     object
# dtypes: object(5)
# memory usage: 7.9+ KB

# %%
df["department"].value_counts()
# Out:
# department
# Training                    23
# Human Resources             20
# Services                    20
# Accounting                  19
# Business Development        18
# Product Management          17
# Research and Development    16
# Marketing                   16
# Sales                       15
# Engineering                 14
# Legal                       13
# Support                      9
# Name: count, dtype: int64

# %%
df[~df["salary"].isna()].head(100)
# Out:
#      first_name    last_name                department  \
# 2        Isiahi     Scholtis  Research and Development
# 4     Jacquette        Duffy               Engineering
# 5        Saleem      Ridolfi                   Support
# 6       Tremain       Ranald               Engineering
# 8    Michaelina       Sammut               Engineering
# ..          ...          ...                       ...
# 190       Becca     Greveson                     Sales
# 194       Quinn      Speddin  Research and Development
# 196     Eadmund          Gon                  Training
# 197      Yvette      Brunker                  Services
# 198     Adelind  Stallworthy                 Marketing
#
#                           email    salary
# 2    ischoltis2@accuweather.com     94297
# 4         jduffy4@shinystat.com  365-0023
# 5          sridolfi5@tumblr.com      6435
# 6           tranald6@amazon.com    152891
# 8            msammut8@weibo.com     25610
# ..                          ...       ...
# ...
