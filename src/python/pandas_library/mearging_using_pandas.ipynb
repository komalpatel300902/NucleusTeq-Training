# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("used_cars_data.csv")

# %% [markdown]
# ### creating 2 Data frame  for merging

# %%
df
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
column_list = list(df.columns)
for x in column_list:
    print(df[x].value_counts())
# Out:
# S.No.
# 0       1
# 4818    1
# 4844    1
# 4843    1
# 4842    1
#        ..
# 2413    1
# 2412    1
# 2411    1
# 2410    1
# 7252    1
# Name: count, Length: 7253, dtype: int64
# Name
# Mahindra XUV500 W8 2WD                  55
# Maruti Swift VDI                        49
# Maruti Swift Dzire VDI                  42
# Honda City 1.5 S MT                     39
# Maruti Swift VDI BSIV                   37
#                                         ..
# Chevrolet Beat LT Option                 1
# Skoda Rapid 1.6 MPI AT Elegance Plus     1
# Ford EcoSport 1.5 TDCi Ambiente          1
# Hyundai i10 Magna 1.1 iTech SE           1
# Hyundai Elite i20 Magna Plus             1
# Name: count, Length: 2041, dtype: int64
# Location
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: count, dtype: int64
# Year
# ...

# %%
df1 = df[["Transmission","Location","Year"]].head(100)

# %%
df2 = df[["Fuel_Type","Location","Owner_Type"]].tail(100)

# %%
df1
# Out:
#    Transmission    Location  Year
# 0        Manual      Mumbai  2010
# 1        Manual        Pune  2015
# 2        Manual     Chennai  2011
# 3        Manual     Chennai  2012
# 4     Automatic  Coimbatore  2013
# ..          ...         ...   ...
# 95       Manual     Kolkata  2015
# 96       Manual     Kolkata  2013
# 97       Manual   Ahmedabad  2010
# 98       Manual   Bangalore  2016
# 99       Manual       Delhi  2010
#
# [100 rows x 3 columns]

# %%
df2
# Out:
#      Fuel_Type   Location Owner_Type
# 7153    Diesel      Kochi      First
# 7154    Petrol     Mumbai      First
# 7155    Diesel     Mumbai      First
# 7156    Petrol      Kochi      First
# 7157    Diesel  Hyderabad     Second
# ...        ...        ...        ...
# 7248    Diesel  Hyderabad      First
# 7249    Petrol     Mumbai      First
# 7250    Diesel    Kolkata      First
# 7251    Petrol       Pune      Third
# 7252    Diesel      Kochi      First
#
# [100 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Transmission  100 non-null    object
#  1   Location      100 non-null    object
#  2   Year          100 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 7153 to 7252
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fuel_Type   100 non-null    object
#  1   Location    100 non-null    object
#  2   Owner_Type  100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
pd.merge(df1,df2,how = "inner", on="Location")
# Out:
#     Transmission   Location  Year Fuel_Type Owner_Type
# 0         Manual     Mumbai  2010    Petrol      First
# 1         Manual     Mumbai  2010    Diesel      First
# 2         Manual     Mumbai  2010    Petrol      First
# 3         Manual     Mumbai  2010    Petrol      First
# 4         Manual     Mumbai  2010    Petrol      First
# ..           ...        ...   ...       ...        ...
# 995       Manual  Ahmedabad  2008    Diesel      First
# 996       Manual  Ahmedabad  2008    Petrol      First
# 997       Manual  Ahmedabad  2010    Petrol      First
# 998       Manual  Ahmedabad  2010    Diesel      First
# 999       Manual  Ahmedabad  2010    Petrol      First
#
# [1000 rows x 5 columns]
