# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("used_cars_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
refined_dataset = df[["Fuel_Type","Transmission","Name","Owner_Type","Kilometers_Driven","Year"]]

# %%
refined_dataset
# Out:
#      Fuel_Type Transmission  \
# 0          CNG       Manual
# 1       Diesel       Manual
# 2       Petrol       Manual
# 3       Diesel       Manual
# 4       Diesel    Automatic
# ...        ...          ...
# 7248    Diesel       Manual
# 7249    Petrol    Automatic
# 7250    Diesel       Manual
# 7251    Petrol    Automatic
# 7252    Diesel    Automatic
#
#                                                    Name Owner_Type  \
# 0                                Maruti Wagon R LXI CNG      First
# 1                      Hyundai Creta 1.6 CRDi SX Option      First
# 2                                          Honda Jazz V      First
# 3                                     Maruti Ertiga VDI      First
# 4                       Audi A4 New 2.0 TDI Multitronic     Second
# ...                                                 ...        ...
# 7248                  Volkswagen Vento Diesel Trendline      First
# 7249                             Volkswagen Polo GT TSI      First
# ...

# %%
grouped_data = refined_dataset.groupby(by = ["Owner_Type"]).max()

# %%
grouped_data
# Out:
#                Fuel_Type Transmission                                 Name  \
# Owner_Type
# First             Petrol       Manual          Volvo XC90 2007-2015 D5 AWD
# Fourth & Above    Petrol       Manual               Toyota Qualis Fleet A3
# Second            Petrol       Manual                 Volvo XC60 D4 Summum
# Third             Petrol       Manual  Volkswagen Vento Petrol Highline AT
#
#                 Kilometers_Driven  Year
# Owner_Type
# First                     6500000  2019
# Fourth & Above             262000  2016
# Second                     250000  2018
# Third                      255000  2015

# %%
name = []
field1 = []
field2 = []
field3 = []
for x in range(10,20):
    for c in range(5000,6000,100):
        for y in range(10000,20000,1000):
            for z in range(300000,400000,10000):
                name.append(str(x))
                field1.append(c)
                field2.append(y)
                field3.append(z)

# %%
len(name)
# Out:
# 10000

# %%
len(field3)
# Out:
# 10000

# %%
df = pd.DataFrame({
    "name":name,
    "field1":field1,
    "field2":field2,
    "field3":field3
})

# %%
df
# Out:
#      name  field1  field2  field3
# 0      10    5000   10000  300000
# 1      10    5000   10000  310000
# 2      10    5000   10000  320000
# 3      10    5000   10000  330000
# 4      10    5000   10000  340000
# ...   ...     ...     ...     ...
# 9995   19    5900   19000  350000
# 9996   19    5900   19000  360000
# 9997   19    5900   19000  370000
# 9998   19    5900   19000  380000
# 9999   19    5900   19000  390000
#
# [10000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10000 non-null  object
#  1   field1  10000 non-null  int64
#  2   field2  10000 non-null  int64
#  3   field3  10000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 312.6+ KB

# %%
grouped_df = df.groupby(by = "name")

# %% [markdown]
# ####     highest_salary_df = merged_df.groupby('departmentId').apply(lambda x: x[x['salary'] == x['salary'].max()])

# %%
grouped_df.apply(lambda x : x[x["field1"] == x["field1"]])
# Out:
#           name  field1  field2  field3
# name
# 10   0      10    5000   10000  300000
#      1      10    5000   10000  310000
#      2      10    5000   10000  320000
#      3      10    5000   10000  330000
#      4      10    5000   10000  340000
# ...        ...     ...     ...     ...
# 19   9995   19    5900   19000  350000
#      9996   19    5900   19000  360000
#      9997   19    5900   19000  370000
#      9998   19    5900   19000  380000
#      9999   19    5900   19000  390000
#
# [10000 rows x 4 columns]

# %%
grouped_df.apply(lambda x : x[x["field1"] > 5500])
# Out:
#           name  field1  field2  field3
# name
# 10   600    10    5600   10000  300000
#      601    10    5600   10000  310000
#      602    10    5600   10000  320000
#      603    10    5600   10000  330000
#      604    10    5600   10000  340000
# ...        ...     ...     ...     ...
# 19   9995   19    5900   19000  350000
#      9996   19    5900   19000  360000
#      9997   19    5900   19000  370000
#      9998   19    5900   19000  380000
#      9999   19    5900   19000  390000
#
# [4000 rows x 4 columns]

# %%
df
# Out:
#      name  field1  field2  field3
# 0      10    5000   10000  300000
# 1      10    5000   10000  310000
# 2      10    5000   10000  320000
# 3      10    5000   10000  330000
# 4      10    5000   10000  340000
# ...   ...     ...     ...     ...
# 9995   19    5900   19000  350000
# 9996   19    5900   19000  360000
# 9997   19    5900   19000  370000
# 9998   19    5900   19000  380000
# 9999   19    5900   19000  390000
#
# [10000 rows x 4 columns]

# %%
df["field4"] = 4

# %%
df
# Out:
#      name  field1  field2  field3  field4
# 0      10    5000   10000  300000       4
# 1      10    5000   10000  310000       4
# 2      10    5000   10000  320000       4
# 3      10    5000   10000  330000       4
# 4      10    5000   10000  340000       4
# ...   ...     ...     ...     ...     ...
# 9995   19    5900   19000  350000       4
# 9996   19    5900   19000  360000       4
# 9997   19    5900   19000  370000       4
# 9998   19    5900   19000  380000       4
# 9999   19    5900   19000  390000       4
#
# [10000 rows x 5 columns]

# %%
def c_add(x):
    x["field5"] = x["field1"].mean()
    return x

# %%
print(grouped_df.apply(c_add).to_string())
# Out:
#           name  field1  field2  field3  field4  field5
# name
# 10   0      10    5000   10000  300000       4  5450.0
#      1      10    5000   10000  310000       4  5450.0
#      2      10    5000   10000  320000       4  5450.0
#      3      10    5000   10000  330000       4  5450.0
#      4      10    5000   10000  340000       4  5450.0
#      5      10    5000   10000  350000       4  5450.0
#      6      10    5000   10000  360000       4  5450.0
#      7      10    5000   10000  370000       4  5450.0
#      8      10    5000   10000  380000       4  5450.0
#      9      10    5000   10000  390000       4  5450.0
#      10     10    5000   11000  300000       4  5450.0
#      11     10    5000   11000  310000       4  5450.0
#      12     10    5000   11000  320000       4  5450.0
#      13     10    5000   11000  330000       4  5450.0
#      14     10    5000   11000  340000       4  5450.0
#      15     10    5000   11000  350000       4  5450.0
# ...
